backgroundcolor="transparent" maxwidth="1600px" height="[object Object]" responsiveprops="[object Object]" boxshadow="none"><div class="product-cardstyles__CardStyled-sc-1uwpde0-0 bTCFJV cardstyles__Card-yvvqkp-0 gXxQWo" height="auto" width="auto"><div class="product-cardstyles__Container-sc-1uwpde0-1 hNTkow"><a href="/produto/176209/leite-longa-vida-desnatado-italac-1l" font-size="16" font-family="primaryMedium" class="hyperlinkstyles__Link-j02w35-0 glclGF"><div class="placeholderstyles__PlaceholderContainer-ix9p6w-0 product-cardstyles__ImageDiv-sc-1uwpde0-2 BBQiP"><div class="lazyload-wrapper "><img src="https://static.clubeextra.com.br/img/uploads/1/804/529804.jpg?im=Resize,width=200" alt="Leite Longa Vida Desnatado ITALAC 1L" width="120" height="120" class="product-cardstyles__Image-sc-1uwpde0-3 beZujn"></div></div></a><div class="product-cardstyles__InnerContainer-sc-1uwpde0-4 elHAFy"><a href="/produto/176209/leite-longa-vida-desnatado-italac-1l" font-size="16" font-family="primaryMedium" class="hyperlinkstyles__Link-j02w35-0 glclGF"><div class="product-cardstyles__Top-sc-1uwpde0-6 gDBBEX"><text class="product-cardstyles__Text-sc-1uwpde0-7 hXaJKO"><a href="/produto/176209/leite-longa-vida-desnatado-italac-1l" class="product-cardstyles__Link-sc-1uwpde0-9 bSQmwP hyperlinkstyles__Link-j02w35-0 iMacJg" font-size="16" font-family="primaryMedium">Leite Longa Vida Desnatado ITALAC 1L</a></text></div><div class="product-cardstyles__Middle-sc-1uwpde0-10 gVMhWm"><div class="placeholderstyles__PlaceholderContainer-ix9p6w-0 product-cardstyles__Price-sc-1uwpde0-11 CkMFa"><div class="MuiGrid-root gridstyles-sc-6scn59-0 jBgNpA MuiGrid-align-items-xs-center" minheight="45px" display="flex" backgroundcolor="transparent" maxwidth="1600px" height="[object Object]" boxshadow="none"><div class="MuiGrid-grid-xs-12 MuiGrid-grid-sm-12 MuiGrid-grid-md-12 MuiGrid-grid-lg-12 MuiGrid-grid-xl-12    column__Column-sc-3wioyv-0 jTENom"><div class="sealsstyles__SealsStyled-sc-173rinj-0 iawOji"><div size="16" class="price-tag-normalstyle__LabelPrice-sc-1co9fex-0 lkWvql">R$5,49</div></div></div></div></div></div></a><div class="product-cardstyles__Bottom-sc-1uwpde0-12 cpXBBC"><div class="product-cardstyles__Item-sc-1uwpde0-13 mARzx"></div><div class="product-cardstyles__Item-sc-1uwpde0-13 mARzx"><a target="_self" text-decoration="none" class="buttonstyles__Link-sc-1mux0mx-4 emjeOa"><button class="primary buttonstyles__ButtonStyle-sc-1mux0mx-0 kyLjQy"><span font-family="primarySemiBold" class="buttonstyles__Text-sc-1mux0mx-2 iHGqzy">COMPRAR</span></button></a></div></div></div></div></div></div></div>'''
soup = BeautifulSoup(url, 'html.parser')
#soup.findAll("div", attrs={"class":"price-tag-normalstyle__LabelPrice-sc-1co9fex-0 lkWvql"}):
#print(produto[produto.rfind('<'):produto.find('>')+1:1])
#for produto in range(max):
#print(tabela[0].split('R$'))

tabela = soup.get_text().split('COMPRAR')

print (biblioteca)
for i in range(len(tabela)-1):
    biblioteca = tabela[i].split('R$')
    print (biblioteca[0])
    print (biblioteca[1])
# Out:
# ['Leite NINHO Integral 1L', '6,99']
# Leite NINHO Integral 1L
# 6,99
# Leite Longa Vida Integral QUALITÁ 1 Litro
# 4,99
# Leite Longa Vida Integral  ITALAC 1 Litro
# 5,49
# Leite Desnatado MOLICO 1L
# 6,99
# Leite Integral JUSSARA Garrafa 1 Litro
# 4,89
# Leite Longa Vida Desnatado QUALITÁ 1 Litro
# 4,99
# Leite Semi Desnatado NINHO Levinho 1L
# 6,99
# Leite UHT Integral Piracanjuba Caixa com tampa 1L
# 5,99
# Leite Paulista EDGE Integral 1L
# 5,99
# Leite Longa Vida Integral PARMALAT 1 Litro
# 5,29
# Leite UHT Integral JUSSARA 1 Litro
# 4,89
# Leite Longa Vida Desnatado ITALAC 1L
# 5,49
